# %%
import pandas as pd
dataFrame = pd.read_csv("mycsv.csv")

# %%
print(dataFrame)
# Out:
#    studentID  hoursStudied  marks
# 0          1             1     20
# 1          2             2     35
# 2          3             3     50
# 3          4             4     65
# 4          5             5     80
# 5          6             6     90
# 6          7             7     95

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(dataFrame['hoursStudied'],dataFrame['marks'])
plt.title("Graph")
plt.xlabel("Hours Studied")
plt.ylabel("Marks Scored")
from sklearn.model_selection import train_test_split
x = dataFrame[['hoursStudied']]
y = dataFrame['marks']
# Out:
# Text(0, 0.5, 'Marks Scored')
